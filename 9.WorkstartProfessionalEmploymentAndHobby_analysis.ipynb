# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#plotly imports
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('updatedDatasets/Update3.csv',index_col='Respondent')
pd.set_option('display.max_columns',None)
df.tail(3)
# Out:
#                                                  Professional  \
# Respondent
# 51390                                  Professional developer
# 51391                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                          ProgramHobby        Country University  \
# Respondent
# 51390       Yes, I program as a hobby         Canada         No
# 51391       Yes, I program as a hobby  United States         No
# 51392                              No        Ireland         No
#
#               EmploymentStatus  \
# Respondent
# 51390       Employed full-time
# 51391       Employed full-time
# 51392       Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 51390       Some college/university study without earning ...
# 51391                                       Bachelor's degree
# 51392                                       Bachelor's degree
#
#                                                MajorUndergrad  \
# Respondent
# 51390       Information technology, networking, or system ...
# 51391                Computer science or software engineering
# 51392                Computer science or software engineering
#
#                YearsCodedJob                         DeveloperType  \
# Respondent
# 51390       Less than a year  Web developer; Systems administrator
# 51391           1 to 5 years       Web developer; Mobile developer
# 51392          5 to 10 years                                   NaN
#
#            NonDeveloperType  CareerSatisfaction  JobSatisfaction  \
# Respondent
# 51390                   NaN                10.0             10.0
# 51391                   NaN                 6.0              7.0
# 51392                 Other                 8.0              8.0
#
#             ProblemSolving LearningNewTech     JobSecurity DiversityImportant  \
# Respondent
# 51390                  NaN             NaN             NaN                NaN
# 51391       Strongly agree  Strongly agree  Somewhat agree           Disagree
# 51392                  NaN             NaN             NaN                NaN
#
#                SeriousWork WorkPayCare ChallengeMyself  \
# Respondent
# 51390                  NaN         NaN             NaN
# 51391       Strongly agree    Disagree  Strongly agree
# 51392                  NaN         NaN             NaN
#
#                            LastNewJob  \
# Respondent
# 51390                             NaN
# 51391       Between 2 and 4 years ago
# 51392       Between 2 and 4 years ago
#
#                                             ImportantBenefits  \
# Respondent
# 51390                                                     NaN
# 51391       Equipment; Education sponsorship; Expected wor...
# 51392       Annual bonus; Vacation/days off; Health benefi...
#
#                      JobProfile  \
# Respondent
# 51390       Glassdoor; LinkedIn
# 51391                       NaN
# 51392                  LinkedIn
#
#                                                 LearnedHiring  \
# Respondent
# 51390       I was contacted directly by someone at the com...
# 51391                                                     NaN
# 51392       I was contacted directly by someone at the com...
#
#                      Overpaid  EducationImportant  \
# Respondent
# 51390                     NaN  Not very important
# 51391       Greatly underpaid                 NaN
# 51392                     NaN                 NaN
#
#                                                EducationTypes WorkStart  \
# Respondent
# 51390                         Self-taught; Coding competition       NaN
# 51391                                                     NaN   2:00 PM
# 51392       Online course; Part-time/evening course; Indus...   8:00 AM
#
#                                     HaveWorkedLanguage  \
# Respondent
# 51390                                              NaN
# 51391                           JavaScript; PHP; Swift
# 51392       Java; JavaScript; PHP; Python; Ruby; Swift
#
#                     WantWorkLanguage                 HaveWorkedDatabase  \
# Respondent
# 51390                            NaN                                NaN
# 51391       Clojure; Erlang; Haskell                              MySQL
# 51392                            NaN  MongoDB; Redis; MySQL; PostgreSQL
#
#            WantWorkDatabase HaveWorkedPlatform WantWorkPlatform  \
# Respondent
# 51390                   NaN                NaN              NaN
# 51391                   NaN     iOS; WordPress          Android
# 51392                   NaN                NaN              NaN
#
#                                           IDE             AuditoryEnvironment  \
# Respondent
# 51390                                     NaN                             NaN
# 51391                       Emacs; Vim; Xcode              Turn on some music
# 51392       Notepad++; Eclipse; Visual Studio  Keep the room absolutely quiet
#
#            Gender HighestEducationParents        Salary  ExpectedSalary  \
# Respondent
# 51390         NaN                     NaN  33298.752045             NaN
# 51391        Male     A bachelor's degree  40000.000000             NaN
# 51392        Male     A bachelor's degree  52440.943126             NaN
#
#             Assess_Scoring
# Respondent
# 51390                  NaN
# 51391                 22.5
# 51392                 30.5

# %%
data2 = df[['WorkStart','Country']]
data2.head(2)
# Out:
#            WorkStart         Country
# Respondent
# 1            6:00 AM   United States
# 2           10:00 AM  United Kingdom

# %%
data2['WorkStart'].value_counts()
# Out:
# 9:00 AM     9401
# 10:00 AM    9091
# 8:00 AM     7076
# 7:00 AM     3364
# 11:00 AM    2212
# 6:00 AM     1216
# Noon        1146
# 2:00 PM      443
# 1:00 PM      399
# 5:00 AM      294
# 8:00 PM      280
# 6:00 PM      254
# 4:00 PM      249
# 10:00 PM     212
# 3:00 PM      206
# 9:00 PM      156
# 5:00 PM      134
# 7:00 PM      127
# 4:00 AM      123
# Midnight      90
# 11:00 PM      85
# 1:00 AM       53
# 3:00 AM       50
# 2:00 AM       35
# Name: WorkStart, dtype: int64

# %%
morning=['9:00 AM','10:00 AM','8:00 AM','7:00 AM','11:00 AM','6:00 AM']
noon=['1:00 PM','2:00 PM','3:00 PM','4:00 PM','5:00 PM','6:00 PM','Noon']
evening=['7:00 PM','8:00 PM','9:00 PM','10:00 PM']
night=['11:00 PM','1:00 AM','2:00 AM','Midnight']
beforeMorning=['3:00 AM','4:00 AM','5:00 AM']
def workingTime(x):
    if x in morning:
        return 'morning' 
    elif x in noon:
        return 'noon' 
    elif x in evening:
        return 'evening' 
    elif x in night:
        return 'night' 
    elif x in beforeMorning:
        return 'beforeMorning' 
    else:
        return np.nan
    
data2['WorkStart']=data2['WorkStart'].apply(workingTime)
data2['WorkStart'].value_counts()
# Out:
# morning          32360
# noon              2831
# evening            775
# beforeMorning      467
# night              263
# Name: WorkStart, dtype: int64

# %%
data2.head()
# Out:
#            WorkStart         Country
# Respondent
# 1            morning   United States
# 2            morning  United Kingdom
# 3            morning  United Kingdom
# 4            morning   United States
# 5                NaN     Switzerland

# %%
data2['Country'].value_counts()[:7]
# Out:
# United States     11455
# India              5197
# United Kingdom     4395
# Germany            4143
# Canada             2233
# France             1740
# Poland             1290
# Name: Country, dtype: int64

# %%
L=['United States','India','United Kingdom','Germany','Canada','France','Poland']
data2['Country']=data2['Country'].apply(lambda x: x if x in L else 'Other')
data2.head()
# Out:
#            WorkStart         Country
# Respondent
# 1            morning   United States
# 2            morning  United Kingdom
# 3            morning  United Kingdom
# 4            morning   United States
# 5                NaN           Other

# %%
df3 = data2.groupby(by=['Country','WorkStart']).size()
df3=df3.to_frame()
df3
# Out:
#                                   0
# Country        WorkStart
# Canada         beforeMorning     21
#                evening           15
#                morning         1587
#                night              8
#                noon              78
# France         beforeMorning      9
#                evening           20
#                morning         1115
#                night              6
#                noon              69
# Germany        beforeMorning     26
#                evening           46
#                morning         2797
#                night              9
#                noon             210
# India          beforeMorning     65
#                evening          141
#                morning         2188
#                night             58
#                noon             372
# Other          beforeMorning    181
#                evening          385
#                morning        12309
#                night            157
#                noon            1403
# Poland         beforeMorning      6
#                evening           20
#                morning          872
#                night              3
#                noon              61
# United Kingdom beforeMorning     24
#                evening           42
#                morning         3193
#                night              6
#                noon             162
# United States  beforeMorning    135
#                evening          106
#                morning         8299
#                night             16
#                noon             476

# %%
df3 = df3.reset_index()
df3.columns=['Country','WorkStart','Count']
df3.head()
# Out:
#   Country      WorkStart  Count
# 0  Canada  beforeMorning     21
# 1  Canada        evening     15
# 2  Canada        morning   1587
# 3  Canada          night      8
# 4  Canada           noon     78

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='WorkStart',y='Count',hue='Country',data=df3)
plt.title('Most Favourable start time for work')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Professional'])
plt.xticks(rotation=90)
plt.title('Analyzing type of crowd on Stackoverflow')
plt.show()
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['EmploymentStatus'])
plt.xticks(rotation=90)
plt.title('Analyzing type of crowd on Stackoverflow')
plt.show()
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['ProgramHobby'].unique()
# Out:
# array(['Yes, both', 'Yes, I program as a hobby', 'No',
#        'Yes, I contribute to open source projects'], dtype=object)

# %%
plt.figure(figsize=(10,6))
plt.pie(df['ProgramHobby'].value_counts(), labels = df['ProgramHobby'].value_counts().index,
        startangle=90, wedgeprops={'edgecolor': 'black'}, autopct='%1.f%%', shadow=True)
plt.title("Hobby of the crowd on stackoverflow")
plt.show()
